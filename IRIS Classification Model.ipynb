# %%
import numpy
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
# Out:
# Using TensorFlow backend.

# %%
seed = 7
numpy.random.seed(seed)

# %%
# load dataset
dataframe = pandas.read_csv("iris.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:4].astype(float)
Y = dataset[:,4]

# %%
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = np_utils.to_categorical(encoded_Y)

# %%
from keras import models
from keras import layers

def baseline_model():
    
    model = models.Sequential()
    
    
    model.add(layers.Dense(15, activation='relu', input_dim=4))
    model.add(layers.Dense(8, activation='tanh'))
    model.add(layers.Dense(3, activation='softmax'))
              
              
    model.compile(optimizer = 'Adam',loss='binary_crossentropy',metrics=['accuracy'])
    


    return model

# %%
estimator = KerasClassifier(build_fn=baseline_model, epochs=200, batch_size=5, verbose=1)

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)

# %%
results = cross_val_score(estimator, X, dummy_y, cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Epoch 1/200
# 135/135 [==============================] - 2s 13ms/step - loss: 0.7507 - acc: 0.5457
# Epoch 2/200
# 135/135 [==============================] - 0s 393us/step - loss: 0.6490 - acc: 0.6099
# Epoch 3/200
# 135/135 [==============================] - 0s 385us/step - loss: 0.5758 - acc: 0.6667
# Epoch 4/200
# 135/135 [==============================] - 0s 378us/step - loss: 0.5027 - acc: 0.7358
# Epoch 5/200
# 135/135 [==============================] - 0s 400us/step - loss: 0.4510 - acc: 0.8593
# Epoch 6/200
# 135/135 [==============================] - 0s 393us/step - loss: 0.4117 - acc: 0.8741
# Epoch 7/200
# 135/135 [==============================] - 0s 379us/step - loss: 0.3849 - acc: 0.8716
# Epoch 8/200
# 135/135 [==============================] - 0s 386us/step - loss: 0.3622 - acc: 0.8667
# Epoch 9/200
# 135/135 [==============================] - 0s 385us/step - loss: 0.3450 - acc: 0.8716
# Epoch 10/200
# ...

# %%
from keras import models
from keras import layers

def baseline_model():
    
    model = models.Sequential()
    
    
    model.add(layers.Dense(150, activation='relu', input_dim=4))
    model.add(layers.Dense(70, activation='tanh'))
    model.add(layers.Dense(3, activation='softmax'))
              
              
    model.compile(optimizer = 'Adam',loss='binary_crossentropy',metrics=['accuracy'])
    


    return model

# %%
estimator = KerasClassifier(build_fn=baseline_model, epochs=200, batch_size=5, verbose=1)

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)

# %%
results = cross_val_score(estimator, X, dummy_y, cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Epoch 1/200
# 135/135 [==============================] - 3s 22ms/step - loss: 0.4689 - acc: 0.7951
# Epoch 2/200
# 135/135 [==============================] - 0s 475us/step - loss: 0.3156 - acc: 0.8321
# Epoch 3/200
# 135/135 [==============================] - 0s 475us/step - loss: 0.2389 - acc: 0.9309
# Epoch 4/200
# 135/135 [==============================] - 0s 467us/step - loss: 0.1992 - acc: 0.9580
# Epoch 5/200
# 135/135 [==============================] - 0s 467us/step - loss: 0.1752 - acc: 0.9580
# Epoch 6/200
# 135/135 [==============================] - 0s 475us/step - loss: 0.1367 - acc: 0.9802
# Epoch 7/200
# 135/135 [==============================] - 0s 467us/step - loss: 0.1389 - acc: 0.9704
# Epoch 8/200
# 135/135 [==============================] - 0s 467us/step - loss: 0.1014 - acc: 0.9753
# Epoch 9/200
# 135/135 [==============================] - 0s 475us/step - loss: 0.0867 - acc: 0.9778
# Epoch 10/200
# ...

# %%
from keras import models
from keras import layers

def baseline_model():
    
    model = models.Sequential()
    
    
    model.add(layers.Dense(6, activation='relu', input_dim=4))
    model.add(layers.Dense(8, activation='tanh'))
    model.add(layers.Dense(3, activation='softmax'))
              
              
    model.compile(optimizer = 'Adam',loss='binary_crossentropy',metrics=['accuracy'])
    


    return model

# %%
estimator = KerasClassifier(build_fn=baseline_model, epochs=200, batch_size=5, verbose=1)

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)

# %%
results = cross_val_score(estimator, X, dummy_y, cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Epoch 1/200
# 135/135 [==============================] - 4s 26ms/step - loss: 0.7117 - acc: 0.5778
# Epoch 2/200
# 135/135 [==============================] - 0s 504us/step - loss: 0.6799 - acc: 0.6667
# Epoch 3/200
# 135/135 [==============================] - 0s 489us/step - loss: 0.6633 - acc: 0.6667
# Epoch 4/200
# 135/135 [==============================] - 0s 482us/step - loss: 0.6530 - acc: 0.6667
# Epoch 5/200
# 135/135 [==============================] - 0s 489us/step - loss: 0.6455 - acc: 0.6667
# Epoch 6/200
# 135/135 [==============================] - 0s 504us/step - loss: 0.6397 - acc: 0.6667
# Epoch 7/200
# 135/135 [==============================] - 0s 489us/step - loss: 0.6348 - acc: 0.6667
# Epoch 8/200
# 135/135 [==============================] - 0s 490us/step - loss: 0.6304 - acc: 0.6667
# Epoch 9/200
# 135/135 [==============================] - 0s 489us/step - loss: 0.6257 - acc: 0.6667
# Epoch 10/200
# ...

# %%
from keras import models
from keras import layers

def baseline_model():
    
    model = models.Sequential()
    
    
    model.add(layers.Dense(150, activation='relu', input_dim=4))
    model.add(layers.Dense(90, activation='sigmoid'))
    model.add(layers.Dense(30, activation='linear'))
    model.add(layers.Dense(8, activation='tanh'))
    model.add(layers.Dense(3, activation='softmax'))
              
              
    model.compile(optimizer = 'Adam',loss='binary_crossentropy',metrics=['accuracy'])
    


    return model

# %%
estimator = KerasClassifier(build_fn=baseline_model, epochs=400, batch_size=3, verbose=1)

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)

# %%
results = cross_val_score(estimator, X, dummy_y, cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Epoch 1/400
# 135/135 [==============================] - 5s 34ms/step - loss: 0.5966 - acc: 0.6741
# Epoch 2/400
# 135/135 [==============================] - 0s 971us/step - loss: 0.4658 - acc: 0.7704
# Epoch 3/400
# 135/135 [==============================] - 0s 956us/step - loss: 0.3631 - acc: 0.8000
# Epoch 4/400
# 135/135 [==============================] - 0s 941us/step - loss: 0.3257 - acc: 0.8173
# Epoch 5/400
# 135/135 [==============================] - 0s 964us/step - loss: 0.3149 - acc: 0.8148
# Epoch 6/400
# 135/135 [==============================] - 0s 964us/step - loss: 0.2825 - acc: 0.9210
# Epoch 7/400
# 135/135 [==============================] - 0s 972us/step - loss: 0.2357 - acc: 0.9605
# Epoch 8/400
# 135/135 [==============================] - 0s 971us/step - loss: 0.1827 - acc: 0.9728
# Epoch 9/400
# 135/135 [==============================] - 0s 971us/step - loss: 0.1436 - acc: 0.9654
# Epoch 10/400
# ...

# %%
from keras import models
from keras import layers

def baseline_model():
    
    model = models.Sequential()
    
    
    model.add(layers.Dense(150, activation='relu', input_dim=4))
    model.add(layers.Dense(90, activation='sigmoid'))
    model.add(layers.Dense(30, activation='linear'))
    model.add(layers.Dense(8, activation='tanh'))
    model.add(layers.Dense(3, activation='softmax'))
              
              
    model.compile(optimizer = 'Adam',loss='mse',metrics=['accuracy'])
    


    return model

# %%
estimator = KerasClassifier(build_fn=baseline_model, epochs=100, batch_size=50, verbose=1)

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)

# %%
results = cross_val_score(estimator, X, dummy_y, cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Epoch 1/100
# 135/135 [==============================] - 5s 39ms/step - loss: 0.2071 - acc: 0.5111
# Epoch 2/100
# 135/135 [==============================] - 0s 141us/step - loss: 0.1922 - acc: 0.5704
# Epoch 3/100
# 135/135 [==============================] - 0s 148us/step - loss: 0.1748 - acc: 0.6741
# Epoch 4/100
# 135/135 [==============================] - 0s 133us/step - loss: 0.1583 - acc: 0.6815
# Epoch 5/100
# 135/135 [==============================] - 0s 133us/step - loss: 0.1445 - acc: 0.6815
# Epoch 6/100
# 135/135 [==============================] - 0s 111us/step - loss: 0.1327 - acc: 0.6815
# Epoch 7/100
# 135/135 [==============================] - 0s 126us/step - loss: 0.1241 - acc: 0.6815
# Epoch 8/100
# 135/135 [==============================] - 0s 119us/step - loss: 0.1161 - acc: 0.7259
# Epoch 9/100
# 135/135 [==============================] - 0s 104us/step - loss: 0.1097 - acc: 0.7333
# Epoch 10/100
# ...
